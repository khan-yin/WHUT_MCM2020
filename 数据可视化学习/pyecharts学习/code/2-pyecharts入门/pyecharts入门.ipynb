# %% [markdown]
# ### 一、安装pyecharts
#
# <span style="color:red">注意：请使用如下代码安装pyecharts<span/>，视频里面展示的安装方法，现在已经无法使用。
#
# **使用pip命令安装pyecharts：**
# ```python
#  pip install pyecharts==0.4.0
#
# ```
#
# **下面的pip命令是用来安装地图插件的，建议全部安装。如果没有这些地图插件，后面绘制地图的时候你可能会显示异常**
#
# ```
# pip install echarts-countries-pypkg
# pip install echarts-china-provinces-pypkg
# pip install echarts-china-cities-pypkg
# ```

# %% [markdown]
# ### 二、在jupyter notebook中使用pyecharts
#
# #### 复现官网的案例

# %%
from pyecharts import Bar

bar = Bar("我的第一个图表", "这里是副标题")
bar.add("服装", ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"], [5, 20, 36, 10, 75, 90])
bar.render("./html/bar.html")

# %%
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e4c4e74f34eb4f3792128b04d326d60f" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_e4c4e74f34eb4f3792128b04d326d60f = echarts.init(document.getElementById('e4c4e74f34eb4f3792128b04d326d60f'), 'light', {renderer: 'canvas'});
#
# var option_e4c4e74f34eb4f3792128b04d326d60f = {
#     "title": [
#         {
#             "text": "\u6211\u7684\u7b2c\u4e00\u4e2a\u56fe\u8868",
#             "subtext": "\u8fd9\u91cc\u662f\u526f\u6807\u9898",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
# ...

# %% [markdown]
# ### 三、在pycharm中使用pycharts
#
# #### 使用pycharm的好处：
#
# - 有代码的自动提示；
# - 方便将数据，样式配置文件，绘图代码放在不同的文件中，代码结构清晰；
# - 便于快速浏览
