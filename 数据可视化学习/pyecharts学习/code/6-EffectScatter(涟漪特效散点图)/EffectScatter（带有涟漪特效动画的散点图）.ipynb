# %%
from pyecharts import EffectScatter

v1 = [10, 20, 30, 40, 50, 60]
v2 = [25, 20, 15, 10, 60, 33]

es = EffectScatter("动态散点图示例")

es.add("effectScatter", v1, v2)
es.render()
es
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="bcf5f037af574081bd349f709236da0d" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_bcf5f037af574081bd349f709236da0d = echarts.init(document.getElementById('bcf5f037af574081bd349f709236da0d'), null, {renderer: 'canvas'});
# var option_bcf5f037af574081bd349f709236da0d = {
#     "title": [
#         {
#             "text": "\u52a8\u6001\u6563\u70b9\u56fe\u793a\u4f8b",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 1222554,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "effectScatter",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     10,
#                     25
#                 ],
#                 [
#                     20,
#                     20
#                 ],
#                 [
#                     30,
#                     15
#                 ],
#                 [
#                     40,
#                     10
#                 ],
#                 [
#                     50,
#                     60
#                 ],
#                 [
#                     60,
#                     33
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 1222554
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "effectScatter"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "data": null,
#             "type": "value"
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_bcf5f037af574081bd349f709236da0d.setOption(option_bcf5f037af574081bd349f709236da0d);
#
#     });
# </script>

# %%
es = EffectScatter("动态散点图各种图形示例")
es.add("", [10], [10], symbol_size=20, effect_scale=3.5,
       effect_period=3, symbol="pin")
es.add("", [20], [20], symbol_size=12, effect_scale=4.5,
       effect_period=4,symbol="rect")
es.add("", [30], [30], symbol_size=30, effect_scale=5.5,
       effect_period=5,symbol="roundRect")
es.add("", [40], [40], symbol_size=30, effect_scale=6.5,
       effect_brushtype='fill',symbol="roundRect")
es.add("", [50], [50], symbol_size=16, effect_scale=5.5,
       effect_period=3,symbol="arrow")
es.add("", [60], [60], symbol_size=6, effect_scale=2.5,
       effect_period=3,symbol="triangle")
es.render()
es
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="5f2aff6fbbbc4c5887bbc8cc8068e7f2" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_5f2aff6fbbbc4c5887bbc8cc8068e7f2 = echarts.init(document.getElementById('5f2aff6fbbbc4c5887bbc8cc8068e7f2'), null, {renderer: 'canvas'});
# var option_5f2aff6fbbbc4c5887bbc8cc8068e7f2 = {
#     "title": [
#         {
#             "text": "\u52a8\u6001\u6563\u70b9\u56fe\u5404\u79cd\u56fe\u5f62\u793a\u4f8b",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 1891192,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "brushType": "stroke",
#                 "scale": 3.5,
#                 "period": 3
#             },
#             "symbol": "pin",
#             "symbolSize": 20,
#             "data": [
#                 [
#                     10,
#                     10
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 1891192
#         },
#         {
#             "type": "effectScatter",
#             "name": "",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "brushType": "stroke",
#                 "scale": 4.5,
#                 "period": 4
#             },
#             "symbol": "rect",
#             "symbolSize": 12,
#             "data": [
#                 [
#                     20,
#                     20
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 1891192
#         },
#         {
#             "type": "effectScatter",
#             "name": "",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "brushType": "stroke",
#                 "scale": 5.5,
#                 "period": 5
#             },
#             "symbol": "roundRect",
#             "symbolSize": 30,
#             "data": [
#                 [
#                     30,
#                     30
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 1891192
#         },
#         {
#             "type": "effectScatter",
#             "name": "",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "brushType": "fill",
#                 "scale": 6.5,
#                 "period": 4
#             },
#             "symbol": "roundRect",
#             "symbolSize": 30,
#             "data": [
#                 [
#                     40,
#                     40
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 1891192
#         },
#         {
#             "type": "effectScatter",
#             "name": "",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "brushType": "stroke",
#                 "scale": 5.5,
#                 "period": 3
#             },
#             "symbol": "arrow",
#             "symbolSize": 16,
#             "data": [
#                 [
#                     50,
#                     50
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 1891192
#         },
#         {
#             "type": "effectScatter",
#             "name": "",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 3
#             },
#             "symbol": "triangle",
#             "symbolSize": 6,
#             "data": [
#                 [
#                     60,
#                     60
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {

# %%
import pandas as pd 
df = pd.read_csv("./data/scatter.csv",encoding="gbk")

# %%
df.head()
# Out:
#    实验编号  国家  电脑性能  芯片质量
# 0     1  美国   428   201
# 1     2  美国   471   236
# 2     3  美国   439   221
# 3     4  美国   425   221
# 4     5  美国   423   211

# %%
电脑性能 = df['电脑性能'].tolist()

# %%
芯片质量 = df['芯片质量'].tolist()

# %%
es = EffectScatter("芯片质量与电脑性能之间的关系")
es.add(" ", 芯片质量, 电脑性能,is_legend_show=False)
es.render()
es
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="2d4d87d9d8ec4c179ec0e01f0c195319" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_2d4d87d9d8ec4c179ec0e01f0c195319 = echarts.init(document.getElementById('2d4d87d9d8ec4c179ec0e01f0c195319'), null, {renderer: 'canvas'});
# var option_2d4d87d9d8ec4c179ec0e01f0c195319 = {
#     "title": [
#         {
#             "text": "\u82af\u7247\u8d28\u91cf\u4e0e\u7535\u8111\u6027\u80fd\u4e4b\u95f4\u7684\u5173\u7cfb",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 1411357,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": " ",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     201,
#                     428
#                 ],
#                 [
#                     236,
#                     471
#                 ],
#                 [
#                     221,
#                     439
#                 ],
#                 [
#                     221,
#                     425
#                 ],
#                 [
#                     211,
#                     423
#                 ],
#                 [
#                     269,
#                     550
#                 ],
#                 [
#                     291,
#                     575
#                 ],
#                 [
#                     286,
#                     561
#                 ],
#                 [
#                     296,
#                     576
#                 ],
#                 [
#                     261,
#                     511
#                 ],
#                 [
#                     186,
#                     254
#                 ],
#                 [
#                     236,
#                     471
#                 ],
#                 [
#                     224,
#                     472
#                 ],
#                 [
#                     246,
#                     504
#                 ],
#                 [
#                     246,
#                     481
#                 ],
#                 [
#                     241,
#                     504
#                 ],
#                 [
#                     231,
#                     461
#                 ],
#                 [
#                     211,
#                     423
#                 ],
#                 [
#                     221,
#                     521
#                 ],
#                 [
#                     296,
#                     576
#                 ],
#                 [
#                     166,
#                     234
#                 ],
#                 [
#                     166,
#                     319
#                 ],
#                 [
#                     168,
#                     320
#                 ],
#                 [
#                     156,
#                     321
#                 ],
#                 [
#                     159,
#                     218
#                 ],
#                 [
#                     117,
#                     218
#                 ],
#                 [
#                     158,
#                     231
#                 ],
#                 [
#                     161,
#                     228
#                 ],
#                 [
#                     166,
#                     225
#                 ],
#                 [
#                     184,
#                     242
#                 ],
#                 [
#                     161,
#                     320
#                 ],
#                 [
#                     286,
#                     481
#                 ],
#                 [
#                     271,
#                     428
#                 ],
#                 [
#                     281,
#                     439
#                 ],
#                 [
#                     164,
#                     215
#                 ],
#                 [
#                     159,
#                     218
#                 ],
#                 [
#                     161,
#                     261
#                 ],
#                 [
#                     166,
#                     234
#                 ],
#                 [
#                     71,
#                     219
#                 ],
#                 [
#                     119,
#                     218
#                 ],
#                 [
#                     171,
#                     353
#                 ],
#                 [
#                     176,
#                     346
#                 ],
#                 [
#                     171,
#                     371
#                 ],
#                 [
#                     159,
#                     371
#                 ],
#                 [
#                     171,
#                     353
#                 ],
#                 [
#                     236,
#                     471
#                 ],
#                 [
#                     246,
#                     521
#                 ],
#                 [
#                     224,
#                     472
#                 ],
#                 [
#                     221,
#                     439
#                 ],
#                 [
#                     251,
#                     504
#                 ],
#                 [
#                     241,
#                     521
#                 ],
#                 [
#                     246,
#                     521
#                 ],
#                 [
#                     181,
#                     379
#                 ],
#                 [
#                     143,
#                     261
#                 ],
#                 [
#                     171,
#                     371
#                 ],
#                 [
#                     159,
#                     371
#                 ],
#                 [
#                     157,
#                     243
#                 ],
#                 [
#                     161,
#                     237
#                 ],
#                 [
#                     141,
#                     200
#                 ],
#                 [
#                     147,
#                     209
#                 ],
#                 [
#                     136,
#                     192
#                 ],
#                 [
#                     140,
#                     193
#                 ],
#                 [
#                     131,
#                     218
#                 ],
#                 [
#                     141,
#                     212
#                 ],
#                 [
#                     166,
#                     234
#                 ],
#                 [
#                     151,
#                     219
#                 ],
#                 [
#                     125,
#                     218
#                 ],
#                 [
#                     161,
#                     261
#                 ],
#                 [
#                     157,
