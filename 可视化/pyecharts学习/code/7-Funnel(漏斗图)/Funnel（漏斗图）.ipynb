# %%
from pyecharts import Funnel

attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
value = [20, 40, 60, 80, 100, 120]
funnel = Funnel("漏斗图示例")
funnel.add("商品", attr, value, is_label_show=True,
           label_pos="inside", label_text_color="#fff")
funnel.render()
funnel
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="31d5e28347f442708f59ef89769d2b53" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_31d5e28347f442708f59ef89769d2b53 = echarts.init(document.getElementById('31d5e28347f442708f59ef89769d2b53'), null, {renderer: 'canvas'});
# var option_31d5e28347f442708f59ef89769d2b53 = {
#     "title": [
#         {
#             "text": "\u6f0f\u6597\u56fe\u793a\u4f8b",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
# ...

# %%
import pandas as pd

# %%
df = pd.read_clipboard()

# %%
df
# Out:
#         阶段   市场金额 上下级转化率 整体转化率
# 0   目标客户市场  50000   100%  100%
# 1   广告送达客户  30000    60%   60%
# 2  了解产品的客户  25000    83%   50%
# 3     用户需求  20000    80%   40%
# 4     意愿购买  15000    75%   30%
# 5      销售额  10000    67%   20%

# %%
阶段 = df['阶段'].tolist()

# %%
市场金额 = df['市场金额'].tolist()

# %%
from pyecharts import Funnel


funnel = Funnel("某产品销售转化路径",title_pos='center')
funnel.add("商品", 阶段, 市场金额, is_label_show=True,
           label_pos="inside", label_text_color="#fff",legend_orient='vertical',legend_pos='left')
funnel.render()
funnel
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3d236beae96245dfb932f0ba358c1b8e" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_3d236beae96245dfb932f0ba358c1b8e = echarts.init(document.getElementById('3d236beae96245dfb932f0ba358c1b8e'), null, {renderer: 'canvas'});
# var option_3d236beae96245dfb932f0ba358c1b8e = {
#     "title": [
#         {
#             "text": "\u67d0\u4ea7\u54c1\u9500\u552e\u8f6c\u5316\u8def\u5f84",
#             "subtext": "",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
# ...
