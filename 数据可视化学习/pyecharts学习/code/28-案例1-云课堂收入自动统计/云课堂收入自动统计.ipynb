# %% [markdown]
# ### 数据预处理

# %%
import pandas as pd
import os
from datetime import datetime

# %% [markdown]
# #### 导入数据

# %%
df = pd.read_excel('./data/'+os.listdir("./data/")[0]).fillna(value=0)

# %%
df.columns
# Out:
# Index(['订单编号', '订单时间', '商品类型', '商品名称', '商品描述', '课程原价(元)', '交易金额(元)', '买家',
#        '推广来源', '推广方名称', '平台红包(元)', '用户实付(元)', '支付方式', '第三方支付费用(元)',
#        '渠道推广费用(元)', '平台服务费用(元)', '商家实际收入（元）', '交易状态', '交易成功时间', '到账状态',
#        '到账时间'],
#       dtype='object')

# %% [markdown]
# #### 汇总总的收入

# %%
df['商家实际收入（元）']=df['平台红包(元)']+df['用户实付(元)']-df['第三方支付费用(元)']-df['渠道推广费用(元)']-df['平台服务费用(元)']

# %%
sum_income = df['商家实际收入（元）'].sum()

# %% [markdown]
# #### 汇总每天的销售收入

# %%
t = df['订单时间'][0]

# %%
t
# Out:
# '2017/11/30 22:44'

# %%
datetime.strptime(t,"%Y/%m/%d %H:%M")
# Out:
# datetime.datetime(2017, 11, 30, 22, 44)

# %%
print(datetime.strptime(t,"%Y/%m/%d %H:%M"))
# Out:
# 2017-11-30 22:44:00

# %%
df['订单日期'] = df['订单时间'].apply(lambda s:datetime.strptime(s,"%Y/%m/%d %H:%M") .date())

# %%
day_income = df.groupby('订单日期')['商家实际收入（元）'].sum()

# %% [markdown]
# #### 汇总top10课程收入数据

# %%
course_income = df.groupby('商品名称')['商家实际收入（元）'].sum().sort_values().tail(10)
course_income
# Out:
# 商品名称
# 从数据到图表—Excel版        477.93
# SQL数据分析              644.02
# 数据获取的N种方式(网络爬虫)      647.03
# Python数据分析           657.20
# 从数据到图表—Tableau版      693.34
# R语言数据分析             1050.33
# 从数据到图表—R语言版         1099.35
# 问卷与量表数据分析           1616.73
# Python基础—数据科学方向     2049.13
# SPSS与统计分析          11119.30
# Name: 商家实际收入（元）, dtype: float64

# %% [markdown]
# #### 汇总top10课程销量

# %%
course_count = df[df['商品名称'].isin(course_income.index)].groupby('商品名称')['订单编号'].count().sort_values()
course_count
# Out:
# 商品名称
# Python数据分析           8
# 从数据到图表—Excel版       14
# 从数据到图表—Tableau版     19
# R语言数据分析             20
# 数据获取的N种方式(网络爬虫)     21
# SQL数据分析             22
# 从数据到图表—R语言版         28
# Python基础—数据科学方向     36
# 问卷与量表数据分析           65
# SPSS与统计分析          133
# Name: 订单编号, dtype: int64

# %% [markdown]
# ### 可视化展示

# %% [markdown]
# #### 总的销售收入展示

# %%
from pyecharts import WordCloud

name = ["Total Income: "+str(round(sum_income,0))+'元']

wordcloud = WordCloud("销售收入统计")
value = [1000]
wordcloud.add("", name, value,shape='diamond')
wordcloud.render()
wordcloud
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="e5594d4e758c43948e4bb231e80ce2e7" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_e5594d4e758c43948e4bb231e80ce2e7 = echarts.init(document.getElementById('e5594d4e758c43948e4bb231e80ce2e7'), null, {renderer: 'canvas'});
# var option_e5594d4e758c43948e4bb231e80ce2e7 = {
#     "title": [
#         {
#             "text": "\u9500\u552e\u6536\u5165\u7edf\u8ba1",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3680778,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "name": "Total Income: 20420.0\u5143",
#                     "value": 1000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(39,127,112)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_e5594d4e758c43948e4bb231e80ce2e7.setOption(option_e5594d4e758c43948e4bb231e80ce2e7);
#
#     });
# </script>

# %% [markdown]
# #### 每日课程收入展示

# %%
from pyecharts import Line,Bar,Overlap

day = day_income.index.tolist()
income = day_income.values.round().tolist()

line = Line("")
line.add("", day,income, is_smooth=True, line_width=3,mark_line=["max", "average"],label_color=['red'])

bar_income = Bar("每日课程收入")
bar_income.add("",day,income,label_color=['grey'],is_label_show = True)

overlap = Overlap()
overlap.add(bar_income)
overlap.add(line)
overlap
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="a2d019319bb34a25b8bc5b513cadd9f3" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_a2d019319bb34a25b8bc5b513cadd9f3 = echarts.init(document.getElementById('a2d019319bb34a25b8bc5b513cadd9f3'), null, {renderer: 'canvas'});
# var option_a2d019319bb34a25b8bc5b513cadd9f3 = {
#     "title": [
#         {
#             "text": "\u6bcf\u65e5\u8bfe\u7a0b\u6536\u5165",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 8253735,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "",
#             "data": [
#                 37.0,
#                 372.0,
#                 230.0,
#                 151.0,
#                 186.0,
#                 186.0,
#                 88.0,
#                 72.0,
#                 492.0,
#                 176.0,
#                 210.0,
#                 558.0,
#                 317.0,
#                 28.0,
#                 277.0,
#                 424.0,
#                 294.0,
#                 562.0,
#                 392.0,
#                 204.0,
#                 371.0,
#                 258.0,
#                 175.0,
#                 79.0,
#                 100.0,
#                 295.0,
#                 27.0,
#                 380.0,
#                 106.0,
#                 119.0,
#                 27.0,
#                 1.0,
#                 80.0,
#                 45.0,
#                 72.0,
#                 2.0,
#                 406.0,
#                 592.0,
#                 239.0,
#                 611.0,
#                 25.0,
#                 62.0,
#                 513.0,
#                 174.0,
#                 346.0,
#                 478.0,
#                 522.0,
#                 302.0,
#                 160.0,
#                 226.0,
#                 265.0,
#                 125.0,
#                 1.0,
#                 169.0,
#                 235.0,
#                 116.0,
#                 168.0,
#                 124.0,
#                 201.0,
#                 126.0,
#                 141.0,
#                 62.0,
#                 306.0,
#                 2.0,
#                 151.0,
#                 266.0,
#                 441.0,
#                 142.0,
#                 288.0,
#                 210.0,
#                 188.0,
#                 420.0,
#                 230.0,
#                 491.0,
#                 279.0,
#                 321.0,
#                 319.0,
#                 37.0,
#                 221.0,
#                 300.0,
#                 133.0,
#                 116.0,
#                 230.0,
#                 170.0,
#                 372.0,
#                 187.0,
#                 537.0,
#                 282.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8253735
#         },
#         {
#             "type": "line",
#             "name": "",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": true,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 37.0,
#                 372.0,
#                 230.0,
#                 151.0,
#                 186.0,
#                 186.0,
#                 88.0,
#                 72.0,
#                 492.0,
#                 176.0,
#                 210.0,
#                 558.0,
#                 317.0,
#                 28.0,
#                 277.0,
#                 424.0,
#                 294.0,
#                 562.0,
#                 392.0,
#                 204.0,
#                 371.0,
#                 258.0,
#                 175.0,
#                 79.0,
#                 100.0,
#                 295.0,
#                 27.0,
#                 380.0,
#                 106.0,
#                 119.0,
#                 27.0,
#                 1.0,
#                 80.0,
#                 45.0,
#                 72.0,
#                 2.0,
#                 406.0,
#                 592.0,
#                 239.0,
#                 611.0,
#                 25.0,
#                 62.0,
#                 513.0,
#                 174.0,
#                 346.0,
#                 478.0,
#                 522.0,
#                 302.0,
#                 160.0,
#                 226.0,
#                 265.0,
#                 125.0,
#                 1.0,
#                 169.0,
#                 235.0,
#                 116.0,
#                 168.0,
#                 124.0,
#                 201.0,
#                 126.0,
#                 141.0,
#                 62.0,
#                 306.0,
#                 2.0,
#                 151.0,
#                 266.0,
#                 441.0,
#                 142.0,
#                 288.0,
#                 210.0,
#                 188.0,
#                 420.0,
#                 230.0,
#                 491.0,
#                 279.0,
#                 321.0,
#                 319.0,
#                 37.0,
#                 221.0,
#                 300.0,
#                 133.0,
#                 116.0,
#                 230.0,
#                 170.0,
#                 372.0,
#                 187.0,
#                 537.0,
#                 282.0
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 3,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": null
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0,
#                 "color": null
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "dat

# %% [markdown]
# #### 不同课程收入与销量

# %%
from pyecharts import Bar,Style

style = Style()

style_bar = style.add(
    legend_top="bottom",        # 图例位置
    yaxis_label_textsize=9,     # y轴标签文字大小
    yaxis_rotate=45,            # y轴标签选择角度
    is_label_show = True,       # 展示柱形图上面的数值标签
    label_pos="right",          # 柱形图上面的数值标签显示位置
    label_text_size=12          # 数值标签文本大小
)

course_income = df.groupby('商品名称')['商家实际收入（元）'].sum().sort_values().tail(10)
x = course_income.index.tolist()
y = course_income.values.round(2).tolist()  # 销售额
z = course_count.values.tolist()            # 销售量

bar = Bar("单课销售量与销售额统计","",height=400)
bar.add("销售额",x,y,is_convert=True,yaxis_index=0,**style_bar)
bar.add("销售量",x,z,is_convert=True,yaxis_index=1,**style_bar)
bar.render()
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e9f000398ce94e17bfe83e7965e95bd0" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_e9f000398ce94e17bfe83e7965e95bd0 = echarts.init(document.getElementById('e9f000398ce94e17bfe83e7965e95bd0'), null, {renderer: 'canvas'});
# var option_e9f000398ce94e17bfe83e7965e95bd0 = {
#     "title": [
#         {
#             "text": "\u5355\u8bfe\u9500\u552e\u91cf\u4e0e\u9500\u552e\u989d\u7edf\u8ba1",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 5551380,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u9500\u552e\u989d",
#             "data": [
#                 477.93,
#                 644.02,
#                 647.03,
#                 657.2,
#                 693.34,
#                 1050.33,
#                 1099.35,
#                 1616.73,
#                 2049.13,
#                 11119.3
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "right",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5551380
#         },
#         {
#             "type": "bar",
#             "name": "\u9500\u552e\u91cf",
#             "data": [
#                 8,
#                 14,
#                 19,
#                 20,
#                 21,
#                 22,
#                 28,
#                 36,
#                 65,
#                 133
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "right",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5551380
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9500\u552e\u989d",
#                 "\u9500\u552e\u91cf"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "bottom",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "type": "value"
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "rotate": 45,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 9,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "splitLine": {
#                 "show": true
#             },
#             "data": [
#                 "\u4ece\u6570\u636e\u5230\u56fe\u8868\u2014Excel\u7248",
#                 "SQL\u6570\u636e\u5206\u6790",
#                 "\u6570\u636e\u83b7\u53d6\u7684N\u79cd\u65b9\u5f0f(\u7f51\u7edc\u722c\u866b)",
#                 "Python\u6570\u636e\u5206\u6790",
#                 "\u4ece\u6570\u636e\u5230\u56fe\u8868\u2014Tableau\u7248",
#                 "R\u8bed\u8a00\u6570\u636e\u5206\u6790",
#                 "\u4ece\u6570\u636e\u5230\u56fe\u8868\u2014R\u8bed\u8a00\u7248",
#                 "\u95ee\u5377\u4e0e\u91cf\u8868\u6570\u636e\u5206\u6790",
#                 "Python\u57fa\u7840\u2014\u6570\u636e\u79d1\u5b66\u65b9\u5411",
#                 "SPSS\u4e0e\u7edf\u8ba1\u5206\u6790"
#             ],
#             "type": "category"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_e9f000398ce94e17bfe83e7965e95bd0.setOption(option_e9f000398ce94e17bfe83e7965e95bd0);
#
#     });
# </script>

# %% [markdown]
# #### 将上面的图形展示在一起

# %%
from pyecharts import Page

page = Page()
page.add(wordcloud)
page.add(overlap)
page.add(bar)
page.render('./test01.html')

# %% [markdown]
# ### 将代码整合到一起

# %% [markdown]
# #### 整理代码
#
# 将重复的部分去除，整理成一个完整的代码块

# %%
import pandas as pd
import os
from datetime import datetime
from pyecharts import Line,Page,WordCloud,Bar,Style,Overlap

# 数据预处理
df = pd.read_excel('./data/'+os.listdir("./data/")[0]).fillna(value=0)
df['商家实际收入（元）'] = df['平台红包(元)'] + df['用户实付(元)'] - df['第三方支付费用(元)'] - df['渠道推广费用(元)'] - df['平台服务费用(元)']

# 计算销售总收入
sum_income = df['商家实际收入（元）'].sum()

# 汇总每日销售收入
df['订单日期'] = df['订单时间'].apply(lambda s:datetime.strptime(s,"%Y/%m/%d %H:%M") .date())
day_income = df.groupby('订单日期')['商家实际收入（元）'].sum()

# 汇总top10课程收入
course_income = df.groupby('商品名称')['商家实际收入（元）'].sum().sort_values().tail(10)
course_count = df[df['商品名称'].isin(course_income.index)].groupby('商品名称')['订单编号'].count().sort_values()

# 图表宽度参数
self_width = 900


# 总收入
name = ["Total Income: "+str(round(sum_income,0))+'元']
value = [1000]
wordcloud = WordCloud("总的销售收入统计",width = self_width,height=150)
wordcloud.add("", name, value,shape='diamond')


# 每日收入
day = day_income.index.tolist()
income = day_income.values.round().tolist()
# 折线图
line = Line("每日课程收入")
line.add("", day,income, is_smooth=True, line_width=3,mark_line=["max", "average"],label_color=['red'])
# 柱形图
bar_income = Bar("每日课程收入")
bar_income.add("",day,income,label_color=['grey'],is_label_show = True)

# 整合每日收入折线图与柱形图
overlap = Overlap(width = self_width,height=350)
overlap.add(bar_income)
overlap.add(line)


# 单个课程收入
x = course_income.index.tolist()
y = course_income.values.round(2).tolist()  # 销售额
z = course_count.values.tolist()            # 销售量

style = Style()

# 柱形图外观设置
style_bar = style.add(
    legend_top="bottom",        # 图例位置
    yaxis_label_textsize=9,     # y轴标签文字大小
    yaxis_rotate=45,            # y轴标签选择角度
    is_label_show = True,       # 展示柱形图上面的数值标签
    label_pos="right",          # 柱形图上面的数值标签显示位置
    label_text_size=12          # 数值标签文本大小
)

bar = Bar("单课销售量与销售额统计",width = self_width,height=400)
bar.add("销售额",x,y)
bar.add("销售量",x,z,is_convert=True,**style_bar)


# 组合输出
page = Page()
page.add(wordcloud)
page.add(overlap)
page.add(bar)
page.render('./test02.html')

# %% [markdown]
# #### 将代码应用其它时期的销售订单数据

# %% [markdown]
# 将data目录下的路径替换成其它数据集，运行代码即可。
