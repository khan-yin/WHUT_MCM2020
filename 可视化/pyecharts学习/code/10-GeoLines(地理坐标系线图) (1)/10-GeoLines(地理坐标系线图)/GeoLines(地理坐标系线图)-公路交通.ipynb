# %% [markdown]
# ### 导入需要使用的库

# %%
import pandas as pd
from pyecharts import GeoLines, Style

# %% [markdown]
# ### 1. geolines官方案例

# %%
from pyecharts import GeoLines, Style

style = Style(
    title_top="#fff",
    title_pos = "center",
    width=1200,
    height=600,
    background_color="#404a59"
)

data_guangzhou = [
    ["广州", "上海"],
    ["广州", "北京"],
    ["广州", "南京"],
    ["广州", "重庆"],
    ["广州", "兰州"],
    ["广州", "杭州"]
]

geolines = GeoLines("GeoLines 示例", **style.init_style)
geolines.add("从广州出发", data_guangzhou, is_legend_show=False)
geolines.render()
geolines
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="136be1e6b3834b88889d49484899beb1" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_136be1e6b3834b88889d49484899beb1 = echarts.init(document.getElementById('136be1e6b3834b88889d49484899beb1'), 'light', {renderer: 'canvas'});
#
# var option_136be1e6b3834b88889d49484899beb1 = {
#     "title": [
#         {
#             "text": "GeoLines \u793a\u4f8b",
#             "left": "center",
#             "top": "#fff",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 7035546,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "lines",
#             "name": "\u4ece\u5e7f\u5dde\u51fa\u53d1",
#             "zlevel": 2,
#             "effect": {
#                 "show": true,
#                 "period": 6,
#                 "trailLength": 0,
#                 "color": "#fff",
#                 "symbol": "circle",
#                 "symbolSize": 5
#             },
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u4e0a\u6d77",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             121.473701,
#                             31.230416
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5317\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             116.407526,
#                             39.90403
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5357\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             118.78,
#                             32.04
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u91cd\u5e86",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             106.551556,
#                             29.563009
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5170\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             103.73,
#                             36.03
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u676d\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             120.19,
#                             30.26
#                         ]
#                     ]
#                 }
#             ],
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u4ece\u5e7f\u5dde\u51fa\u53d1",
#             "zlevel": 2,
#             "coordinateSystem": "geo",
#             "symbolSize": 10,
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": [
#                         118.78,
#                         32.04,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5170\u5dde",
#                     "value": [
#                         103.73,
#                         36.03,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": [
#                         120.19,
#                         30.26,
#                         0
#                     ]
#                 }
#             ],
#             "label": {
#                 "norma

# %% [markdown]
# ### 2. 修改官方案例
#
# 配色网站https://color.adobe.com/zh/explore/newest/

# %%
from pyecharts import GeoLines, Style

style = Style(
    title_color="#BF2441",     # 标题字体改为白色
    title_pos = "center",      # 标题居中 
    width=980,                 # 调整宽和高
    height=600,
    background_color="#011526" # 图像背景颜色
)

style_geo = style.add(
    maptype="china",
    is_label_show=True,
    line_curve=0.1,
    line_opacity=1,
    geo_effect_symbol="plane",
    geo_effect_color='#FF1D00',
    geo_effect_symbolsize=15,
    label_color=['red'],
    label_pos="right",
    label_formatter="{b}",
    label_text_color="#000",
    label_text_size=14,
    geo_normal_color="#fff",
    geo_emphasis_color="#7CE8D5"
)

data_guangzhou = [
    ["广州", "上海"],
    ["广州", "北京"],
    ["广州", "南京"],
    ["广州", "重庆"],
    ["广州", "兰州"],
    ["广州", "杭州"]
]

geolines = GeoLines("GeoLines官方示例修改", **style.init_style)
geolines.add("从广州出发", data_guangzhou, is_legend_show=False,**style_geo)
geolines.render()
geolines
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="bb237ce00448464895a0c468d9368f61" style="width:980px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_bb237ce00448464895a0c468d9368f61 = echarts.init(document.getElementById('bb237ce00448464895a0c468d9368f61'), 'light', {renderer: 'canvas'});
#
# var option_bb237ce00448464895a0c468d9368f61 = {
#     "title": [
#         {
#             "text": "GeoLines\u5b98\u65b9\u793a\u4f8b\u4fee\u6539",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#BF2441",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 506515,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "lines",
#             "name": "\u4ece\u5e7f\u5dde\u51fa\u53d1",
#             "zlevel": 2,
#             "effect": {
#                 "show": true,
#                 "period": 6,
#                 "trailLength": 0,
#                 "color": "#FF1D00",
#                 "symbol": "path://M1705.06,1318.313v-89.254l-319.9-221.799l0.073-208.063c0.521-84.662-26.629-121.796-63.961-121.491c-37.332-0.305-64.482,36.829-63.961,121.491l0.073,208.063l-319.9,221.799v89.254l330.343-157.288l12.238,241.308l-134.449,92.931l0.531,42.034l175.125-42.917l175.125,42.917l0.531-42.034l-134.449-92.931l12.238-241.308L1705.06,1318.313z",
#                 "symbolSize": 15
#             },
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u4e0a\u6d77",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             121.473701,
#                             31.230416
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5317\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             116.407526,
#                             39.90403
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5357\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             118.78,
#                             32.04
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u91cd\u5e86",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             106.551556,
#                             29.563009
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u5170\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             103.73,
#                             36.03
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5e7f\u5dde",
#                     "toName": "\u676d\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             120.19,
#                             30.26
#                         ]
#                     ]
#                 }
#             ],
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0.1,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u4ece\u5e7f\u5dde\u51fa\u53d1",
#             "zlevel": 2,
#             "coordinateSystem": "geo",
#             "symbolSize": 10,
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": [
#                         118.78,
#                         32.04,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5170\u5dde",
#                     "value": [
#                         103.73,
#                         36.03,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [

# %% [markdown]
# ### 3.南宁与周边城市的公路联系的相关数据预处理

# %% [markdown]
# ####  汽车班次数据获取：
#
# - 部分城市的汽车班次数据可以从这个网站获取，网址为：https://www.changtu.com/chezhan/
# - 获取的数据保存到Excel中，然后倒入Python进行预处理

# %%
roads = pd.read_excel('./data/公路数据.xlsx')
roads.head()
# Out:
#         出发地  目的地
# 0  南宁市琅东汽车站  北海市
# 1  南宁市琅东汽车站  广州市
# 2  南宁市琅东汽车站  深圳市
# 3  南宁市琅东汽车站  柳州市
# 4  南宁市琅东汽车站  桂林市

# %%
roads['出发地'] = "南宁"

# %%
roads['目的地'] = roads['目的地'].apply(lambda s:s.strip("市"))
roads.head()
# Out:
#   出发地 目的地
# 0  南宁  北海
# 1  南宁  广州
# 2  南宁  深圳
# 3  南宁  柳州
# 4  南宁  桂林

# %%
roads = roads.drop_duplicates()

# %%
road_pairs = roads.values.tolist()

# %%
road_pairs
# Out:
# [['南宁', '北海'],
#  ['南宁', '广州'],
#  ['南宁', '深圳'],
#  ['南宁', '柳州'],
#  ['南宁', '桂林'],
#  ['南宁', '防城港'],
#  ['南宁', '玉林'],
#  ['南宁', '梧州'],
#  ['南宁', '钦州'],
#  ['南宁', '贵港'],
#  ['南宁', '东莞'],
#  ['南宁', '东兴'],
#  ['南宁', '来宾'],
#  ['南宁', '百色'],
#  ['南宁', '贺州']]

# %% [markdown]
# ### 4.南宁与其它城市的公路联系可视化展示

# %%
style = Style(
    title_color="#fff",
    title_pos = "center",
    width=980,
    height=600,
    background_color="#404a59"
)

style_geo = style.add(
    maptype="广西",
    is_label_show=True,
    line_curve=0.15,
    line_opacity=0.9,
    legend_pos="right",
    geo_effect_symbol="triangle",
    geo_effect_symbolsize=15,
    label_color=['#a6c84c'],
    label_pos="right",
    label_formatter="{b}",
    label_text_color="#eee",
)

geolines = GeoLines("南宁与其它城市的公路联系", **style.init_style)
geolines.add(name = "从南宁出发",data = road_pairs,is_legend_show=False,**style_geo)
geolines.render('./html/roads.html')
geolines
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-88958ed32a94> in <module>
#      22
#      23 geolines = GeoLines("南宁与其它城市的公路联系", **style.init_style)
# ---> 24 geolines.add(name = "从南宁出发",data = road_pairs,is_legend_show=False,**style_geo)
#      25 geolines.render('./html/roads.html')
#      26 geolines
#
# D:\Anaconda3\lib\site-packages\pyecharts\charts\geolines.py in add(self, name, data, maptype, coordinate_region, symbol, symbol_size, border_color, geo_normal_color, geo_emphasis_color, geo_cities_coords, geo_effect_period, geo_effect_traillength, geo_effect_color, geo_effect_symbol, geo_effect_symbolsize, is_geo_effect_show, is_roam, **kwargs)
#     109             )
#     110             _to_coordinate = self.get_coordinate(
# --> 111                 _to_name, raise_exception=True
#     112             )
#     113             _data_lines.append(
#
# D:\Anaconda3\lib\site-packages\pyecharts\charts\geo.py in get_coordinate(self, name, region, raise_exception)
#      59         coordinate = get_coordinate(name, region=region)
#      60         if coordinate is None and raise_exception:
# ---> 61             raise ValueError("No coordinate is specified for {}".format(name))
#      62
#      63         return coordinate
#
# ValueError: No coordinate is specified for 东兴

# %%
from pyecharts import Geo,Style
import pandas as pd 
#导入excel表举例
df=pd.read_excel('第7题附件1.xlsx')     
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#     967         try:
# --> 968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     126     if result is None:
# --> 127         result = _evaluate_standard(op, op_str, a, b)
#     128
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-daa8c8207ff1> in <module>
#       9                     for i in range(len(df))} #根据文件大小生成字典
#      10 attr=list(df['节点'])   #字典的每个键值
# ---> 11 value=list(df['节点']/100000)  #由于量值的太大，换算以下(散点的颜色就是和这个想关的)
#      12 style = Style(title_color= "#fff",title_pos = "center",
#      13 width = 1200,height = 600,background_color = "#404a59")
#
# D:\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#    1046
#    1047         with np.errstate(all="ignore"):
# -> 1048             result = na_op(lvalues, rvalues)
#    1049         return construct_result(
#    1050             left, result, index=left.index, name=res_name, dtype=None
#
# D:\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#     968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
# --> 970             result = masked_arith_op(x, y, op)
#     971
#     972         return missing.dispatch_fill_zeros(op, x, y, result)
#
# D:\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in masked_arith_op(x, y, op)
#     462         if mask.any():
#     463             with np.errstate(all="ignore"):
# --> 464                 result[mask] = op(xrav[mask], y)
#     465
#     466     result, changed = maybe_upcast_putmask(result, ~mask, np.nan)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
from pyecharts import Geo,Style
import pandas as pd 
 
#导入excel表举例
df=pd.read_excel('流动人口.xlsx')     
df.head()
 
#导入自定义的地点经纬度
geo_cities_coords={df.iloc[i]['地点']:[df.iloc[i]['经度'],df.iloc[i]['纬度']]
                    for i in range(len(df))} #根据文件大小生成字典  
attr=list(df['地点'])   #字典的每个键值
value=list(df['流动人口']/100000)  #由于量值的太大，换算以下(散点的颜色就是和这个想关的)
style = Style(title_color= "#fff",title_pos = "center",
width = 1200,height = 600,background_color = "#404a59")
 
#可视化
geo = Geo('东莞各个CGI总用户数分布',**style.init_style)
geo.add("",attr,value,visual_range=[0,100],symbol_size= 5,
        visual_text_color= "#fff",is_piecewise = True,
        is_visualmap= True,maptype = '东莞', visual_split_number= 10,
        geo_cities_coords=geo_cities_coords)
 
geo.render( '东莞各个CGI总用户数分布.html')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-19f0628f1338> in <module>
#       3
#       4 #导入excel表举例
# ----> 5 df=pd.read_excel('流动人口.xlsx')
#       6 df.head()
#       7
#
# D:\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# D:\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skip_footer, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     308
#     309     if not isinstance(io, ExcelFile):
# --> 310         io = ExcelFile(io, engine=engine)
#     311     elif engine and engine != io.engine:
#     312         raise ValueError(
#
# D:\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     817         self._io = _stringify_path(io)
#     818
# --> 819         self._reader = self._engines[engine](self._io)
#     820
#     821     def __fspath__(self):
#
# D:\Anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# D:\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer)
#     357             self.book = self.load_workbook(filepath_or_buffer)
#     358         elif isinstance(filepath_or_buffer, str):
# --> 359             self.book = self.load_workbook(filepath_or_buffer)
#     360         else:
#     361             raise ValueError(
#
# D:\Anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py in load_workbook(self, filepath_or_buffer)
#      34             return open_workbook(file_contents=data)
#      35         else:
# ---> 36             return open_workbook(filepath_or_buffer)
#      37
#      38     @property
#
# D:\Anaconda3\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: '流动人口.xlsx'
